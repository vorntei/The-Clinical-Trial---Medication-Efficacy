# %% [markdown]
# Dataset: Synthetic data (manually typed lists).
# Goal: Reinforce the Matplotlib Object-Oriented canvas structure and introduce basic Seaborn styling to track how two different medications reduce pain over time.
# 1. Importing Libraries & Theming:
# Start by importing matplotlib.pyplot as plt and import seaborn as sns.
# New Skill: Before creating your plot, use Seaborn to instantly upgrade the visuals by setting a theme. Call sns.set_theme(style="darkgrid").

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 2. The Anatomy / Basic Plotting:
# Create lists to track a 6-hour window.
# hours = [1, 2, 3, 4, 5, 6]
# Create two lists for the medications, representing reported pain levels on a scale of 0 to 10 (e.g., med_A_pain = [8, 6, 5, 3, 2, 2]).
# Set up your canvas using the Object-Oriented method: fig, ax = plt.subplots().
# Plot the data using ax.plot(hours, med_A_pain) and ax.plot(hours, med_B_pain).
# New Skill: Inside your ax.plot() calls, try adding markers and specific colors to differentiate the lines further (e.g., ax.plot(..., color='blue', marker='o', label='Medication A')).
# 3. Basic Customization:
# Instruct the canvas to display your metadata:
# ax.set_title("Pain Level Over Time: Med A vs. Med B")
# ax.set_xlabel("Hours Post-Dose")
# ax.set_ylabel("Reported Pain Level (0-10)")
# Call ax.legend() so the viewer knows which line represents which medication.
# Finally, render the plot cleanly with plt.show().

# %%
sns.set_theme(style="darkgrid")
hours = [1, 2, 3, 4, 5, 6]
med_A_pain = [8, 6, 5, 3, 2, 2]
med_B_pain = [8, 7, 6, 5, 4, 3]
fig, ax = plt.subplots()
ax.plot(
    hours,
    med_A_pain,
    color='blue',
    marker='o',
    label='Medication A'
)
ax.plot(
    hours,
    med_B_pain,
    color='red',
    marker='s',
    label='Medication B'
)
ax.set_title("Pain Level Over Time: Med A vs. Med B")
ax.set_xlabel("Hours Post-Dose")
ax.set_ylabel("Reported Pain Level (0-10)")
ax.legend()
plt.show()

# %% [markdown]
# 4. Explain each of the graphs in details(both Khmer and English)

# %% [markdown]
# This line graph compares how two medications reduce pain over a 6-hour period after taking the medicine.
# The X-axis shows time in hours.
# The Y-axis shows pain level from 0 to 10.
# 0 = no pain, 10 = very severe pain
#
# Medication A (Blue Line)
# The blue line drops quickly from pain level 8 to pain level 2.
# Medication A works faster.The pain decreases significantly within the first 4 hours.
# After hour 5, the pain becomes very low and stable.
# Medication A appears to be more effective for rapid pain relief.
#
# Medication B (Red Line)
# The red line decreases more slowly compared to Medication A.
# Medication B still reduces pain, but at a slower rate.
# The pain level gradually improves over time.
# By hour 6, the pain level is still higher than Medication A.
# Medication B is effective, but its pain relief is slower and less powerful compared to Medication A.

# %% [markdown]
# គោលបំណងរបស់ក្រាហ្វ
# ក្រាហ្វនេះបង្ហាញការប្រៀបធៀបថ្នាំ ២ ប្រភេទ ក្នុងការបន្ថយការឈឺចាប់រយៈពេល ៦ ម៉ោង បន្ទាប់ពីលេបថ្នាំ។
# អ័ក្ស X = ចំនួនម៉ោង
# អ័ក្ស Y = កម្រិតការឈឺចាប់ (0 ដល់ 10)
#
# ថ្នាំ A (បន្ទាត់ពណ៌ខៀវ)
# បន្ទាត់ពណ៌ខៀវធ្លាក់ចុះលឿនពី 8 ទៅ 2។
# ថ្នាំ A មានប្រសិទ្ធភាពលឿនអាចបន្ថយការឈឺចាប់បានច្រើនក្នុងរយៈពេលខ្លីក្រោយម៉ោងទី 5 ការឈឺចាប់ស្ទើរតែបាត់
# ថ្នាំ A មានប្រសិទ្ធភាពល្អសម្រាប់បំបាត់ការឈឺចាប់លឿន។
#
# ថ្នាំ B (បន្ទាត់ពណ៌ក្រហម)
# បន្ទាត់ពណ៌ក្រហមធ្លាក់ចុះយឺតជាងថ្នាំ A។
# ថ្នាំ B ក៏អាចបន្ថយការឈឺបាន
# ប៉ុន្តែការបន្ថយមានល្បឿនយឺតជាង
# នៅម៉ោងទី 6 ការឈឺនៅតែខ្ពស់ជាងថ្នាំ A
# ថ្នាំ B មានប្រសិទ្ធភាព ប៉ុន្តែមិនលឿន និងមិនខ្លាំងដូចថ្នាំ A ទេ។
